# %% [markdown]
# ## Data Filtering and Selection

# %%
# !pip install --upgrade pip 
# !pip install pandas

# %% [markdown]
# #### Comparison operators (> < = <= => == !=) and Masking.

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
numbers_df = DataFrame(np.arange(0, 90, 3).reshape((10, 3)), index=("row 1", "row2", "row3","row4", "row5", "row6", "row7", "row8","row9", "row10"), columns=("column1", "column2", "column3"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 numbers_df = DataFrame(np.arange(0, 90, 3).reshape((10, 3)), index=("row 1", "row2", "row3","row4", "row5", "row6", "row7", "row8","row9", "row10"), columns=("column1", "column2", "column3"))
#
# NameError: name 'DataFrame' is not defined
